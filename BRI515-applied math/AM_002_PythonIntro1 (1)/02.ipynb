# %% [markdown]
# # print Statement

# %% [markdown]
# The **print** statement can be used in the following different ways :
#
#     - print("Hello World")
#     - print("Hello", <Variable Containing the String>)
#     - print("Hello" + <Variable Containing the String>)
#     - print("Hello %s" % <variable containing the string>)

# %%
print("Hello World")

# %% [markdown]
# In Python, single, double and triple quotes are used to denote a string.
# Most people tend to use single quotes when declaring a single character, double quotes when declaring a line, and triple quotes when declaring a paragraph/multiple lines. This is, however, only one of many possible conventions.

# %%
print('Hey')

# %%
print("""My name is Christian
I used to work a lot in Matlab, but
nowadays I also often dabble in Python.""")

# %% [markdown]
# Strings can be assigned to variable say _string1_ and _string2_ which can be called when using the print statement.

# %%
string1 = 'World'
print('Hello', string1)

string2 = '!'
print('Hello', string1, string2)

# %% [markdown]
# String concatenation is the "addition" of two strings. Observe that while concatenating there will be no white space between the strings, so that you would need to add them yourself using +' '

# %%
print('Hello' + string1 + string2)

# %%
print('Hello' + ' ' + string1 + string2)

# %% [markdown]
# **%s** is used to refer to a variable which contains a string.

# %%
print("Hello %s" % string1)

# %% [markdown]
# Similarly, when using other data types
#
#     - %s -> string
#     - %d -> Integer
#     - %f -> Float
#     - %o -> Octal
#     - %x -> Hexadecimal
#     - %e -> exponential
#
# This can be used for conversions inside the print(statement itself.

# %%
print("Actual Number = %d" %18)
print("Float of the number = %f" %18)
print("Octal equivalent of the number = %o" %18)
print("Hexadecimal equivalent of the number = %x" %18)
print("Exponential equivalent of the number = %e" %18)

# %% [markdown]
# When referring to multiple variables, you will need to use a parenthesis.

# %%
print("Hello %s %s" %(string1,string2))

# %% [markdown]
# ## Other Examples

# %% [markdown]
# The following are other different ways the print statement can be put to use. Note the use of special characters '\n' (new-line) and '\t' (tab)

# %%
print("I want %%d to be printed %s" %'here')

# %%
print('_A'*10)

# %%
print("Jan\nFeb\nMar\nApr\nMay\nJun\nJul\nAug")

# %%
print("I want \\n to be printed.")

# %%
print("""
Routine:
\t- Eat
\t- Sleep\n\t- Repeat
""")

# %% [markdown]
# # PrecisionWidth and FieldWidth

# %% [markdown]
# Fieldwidth is the width of the entire number and precision is the width towards the right. One can alter these widths based on the requirements.
#
# The default Precision Width is set to 6.

# %%
"%f" % 3.121312312312

# %% [markdown]
# Notice up to 6 decimal points are returned. To specify the number of decimal points, '%(fieldwidth).(precisionwidth)f' is used.

# %%
"%.10f" % 3.121312312312

# %% [markdown]
# If the field width is set more than the necessary than the data right aligns itself to adjust to the specified values.

# %%
"%9.5f" % 3.121312312312

# %% [markdown]
# Zero padding is done by adding a 0 at the start of fieldwidth.

# %%
"%020.5f" % 3.121312312312

# %% [markdown]
# For proper alignment, a space can be left blank in the field width so that when a negative number is used, proper alignment is maintained.

# %%
print("% 9f" % 3.121312312312)
print("% 9f" % -3.121312312312)

# %% [markdown]
# an explicit '+' sign can be returned at the beginning of a positive number by adding a + sign at the beginning of the field width.

# %%
print("%+9f" % 3.121312312312)
print("% 9f" % -3.121312312312)

# %% [markdown]
# As mentioned above, the data right aligns itself when the field width mentioned is larger than the actual field width. If you would like left alignment, you can acheive this via specifying a negative symbol in the field width.

# %%
"%-9.3f" % 3.121312312312
